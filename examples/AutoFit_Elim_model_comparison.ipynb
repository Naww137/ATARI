# %%
from ATARI.theory.resonance_statistics import make_res_par_avg
import ATARI.utils.hdf5 as h5io
from matplotlib.pyplot import *
import numpy as np
import pandas as pd
import importlib
import os
from copy import copy
from ATARI.sammy_interface import sammy_classes, sammy_functions, template_creator

from ATARI.ModelData.particle_pair import Particle_Pair
from ATARI.ModelData.experimental_model import Experimental_Model

from ATARI.ModelData.measurement_models.transmission_rpi import Transmission_RPI
from ATARI.ModelData.measurement_models.capture_yield_rpi import Capture_Yield_RPI
from ATARI.syndat.syndat_model import Syndat_Model
from ATARI.syndat.control import syndatOPT
from ATARI.syndat.control import Syndat_Control

from ATARI.AutoFit import chi2_eliminator_v2
from ATARI.AutoFit import elim_addit_funcs

# %%
# %matplotlib widget

# %% [markdown]
# ## AutoFit User Example
#
# This notebook gives an examle how the ATARI.AutoFit module can be used to automatically fit data with no need for a prior.

# %%
# plotting data & fits
# default fig size to output
fig_size = (8,6)
dpi=75

# if we will save images - where to save
savefolder = 'all_data_temp/'
if not os.path.exists(savefolder):
    # If it doesn't exist, create it
    os.makedirs(savefolder)

def plot_datafits(datasets, experiments, 
    fits=[], fits_chi2=[], f_model_name='fit',
    priors=[], priors_chi2=[], pr_model_name='prior',
    true=[], true_chi2=[], t_model_name ='true',
    true_pars = pd.DataFrame(), 
    prior_pars = pd.DataFrame(),
    fit_pars = pd.DataFrame(),
    title: str = '',
    show_spingroups: bool = True,
    fig_size : tuple = (8,6)
    ):

    colors = ["C1", "C2", "C3", "C4", "C5", "C6", "C7"]
    fig, axes = subplots(2,1, figsize=fig_size, sharex=True)

    for i, exp in enumerate(experiments):
        if exp.reaction == "transmission":
            model_key = "theo_trans"
            iax = 0
        elif exp.reaction == "capture":
            model_key = "theo_xs"
            iax = 1
        else:
            raise ValueError()

        axes[iax].errorbar(datasets[i].E, datasets[i].exp, yerr=datasets[i].exp_unc, zorder=0,
                                                fmt='.', color='black', alpha=0.5, linewidth=1.0, markersize=4, capsize=1, label=exp.title)
        
        if len(fits) != 0:
            if (len(fits_chi2) != 0):
                fit_label = f'{f_model_name} {exp.title} ({fits_chi2[i]})'
            else:
                fit_label = f'{f_model_name} {exp.title}'
            axes[iax].plot(fits[i].E, fits[i][model_key], color='red', zorder=1, lw=1.5, label=fit_label) # colors[i]
        
        if len(priors) != 0:
            if (len(priors_chi2) != 0):
                prior_label = f'{pr_model_name} {exp.title} ({priors_chi2[i]})'
            else:
                prior_label = f'{pr_model_name} {exp.title}'

            axes[iax].plot(priors[i].E, priors[i][model_key], '--', color='orange', zorder=0, lw=1.5, label=prior_label)
        
        if len(true) != 0:
            if (len(true_chi2) != 0):
                true_label = f'{t_model_name} {exp.title} ({true_chi2[i]})'
            else:
                true_label = f'{t_model_name} {exp.title}'
            axes[iax].plot(true[i].E, true[i]['true'], '-', color='green', zorder=1, alpha=0.5, lw=1.5, label=true_label)


    # Set the y-axis limits with additional space for text and capture ymax before changing
    
    y_top_padding = 0.1 
    x_offset = 0.05

    ymax_values = [ax.get_ylim()[1] for ax in axes]  # Store original ymax values for each axis
    for ax in axes:
        ymin, ymax = ax.get_ylim()
        ax.set_ylim(ymin, ymax + y_top_padding)

    font_size = 8
    y_text_shift = 0.01  # Adjust as needed, related to font size
    y_text_positions = [ymax_values[0], ymax_values[1]]

    # show vertical lines for energies
    
    # fits
    for index, res in fit_pars.iterrows():
        res_E = res.E
        # Add vertical lines at the resonance energies to both subplots
        axes[0].axvline(x=res_E, color='red', linestyle='--', linewidth=0.5, alpha=0.3)
        axes[1].axvline(x=res_E, color='red', linestyle='--', linewidth=0.5, alpha=0.3)

        if (show_spingroups):
            # add txt with
            sp_gr_txt = np.round(int(res.J_ID),0)
            
            y_text_position = ymax  # Position the text at the top of the original y-axis limit
            x_text_position = res_E + x_offset
            
            # Show the text to the right of the line
            for i, ax in enumerate(axes):
                y_text_position = ymax_values[i]  # Use original ymax for text position
                #ax.text(x_text_position, y_text_position, str(sp_gr_txt), color='red', verticalalignment='bottom', fontsize=8)

                ax.text(res_E, y_text_positions[i], str(sp_gr_txt), color='red', verticalalignment='bottom', fontsize=font_size)
                y_text_positions[i] -= y_text_shift


    # the same for theoretical positions
    for index, true_res in true_pars.iterrows():

        true_res_energy = true_res.E
        # Add vertical lines at the resonance energies to both subplots
        axes[0].axvline(x=true_res_energy, color='g', linestyle='--', linewidth=0.5, alpha=0.7)
        axes[1].axvline(x=true_res_energy, color='g', linestyle='--', linewidth=0.5, alpha=0.7)

        if (show_spingroups):
            # add txt with
            sp_gr_txt = np.round(true_res.J_ID,0)
            y_text_position = ymax  # Position the text at the top of the original y-axis limit
            x_text_position = true_res_energy
            
            # Show the text to the right of the line
            for i, ax in enumerate(axes):
                y_text_position = ymax_values[i]  # Use original ymax for text position
                ax.text(x_text_position , y_text_position, str(sp_gr_txt), color='g', verticalalignment='bottom', fontsize=8)

    
    for index, res in prior_pars.iterrows():
        # Add vertical lines at the resonance energies to both subplots
        axes[0].axvline(x=res.E, color='orange', linestyle='--', linewidth=0.5, alpha=0.5)
        axes[1].axvline(x=res.E, color='orange', linestyle='--', linewidth=0.5, alpha=0.5)

        
    axes[0].set_ylabel("T")
    axes[1].set_ylabel(r"$Y_{\gamma}$")

    # set title
    fig.suptitle(title, fontsize=14)
    
    # additional info if present
    add_title = ''
    if (true_pars.shape[0]>0):
        add_title+=''+r'$N_{true}$ = '+str(true_pars.shape[0])
        
    if (len(true_chi2)>0):
        add_title+=', $\sum_{ds}\chi^2$ = '+str(np.round(np.sum(true_chi2),3))

    if (prior_pars.shape[0]>0):
        add_title+=', '+r'$N_{prior}$ = '+str(prior_pars.shape[0])
    if (len(priors_chi2)>0):
        add_title+=', $\sum_{ds}\chi^2$ = '+str(np.round(np.sum(priors_chi2),3))

    if (fit_pars.shape[0]>0):
        add_title+=', '+r'$N_{fit}$ = '+str(fit_pars.shape[0])
    if (len(fits_chi2)>0):
        add_title+=', $\sum_{ds}\chi^2$ = '+str(np.round(np.sum(fits_chi2),3))
    
    # end additional info if present
    axes[0].set_title(add_title, fontsize=10)
    

    # ### make it pretty
    for ax in axes:
        # ax.set_xlim([200,250])
        # ax.set_ylim([-0.1,1.1])
        ax.legend(fontsize='small', loc='lower right')

    fig.supxlabel('Energy (eV)')
    fig.tight_layout()

    return fig

# %% [markdown]
# ## First, generate data with Syndat to play with

# %%
### Reaction Model
Ta_pair = Particle_Pair(isotope = "Ta181",
                        resonance_ladder = pd.DataFrame(),
                        formalism = "XCT",
                        energy_range = [200,250],
                        ac = 8.127,
                        M = 180.94803,
                        I = 3,
                        l_max = 2
)

Ta_pair.add_spin_group(Jpi='3.0',
                       J_ID=1,
                       D_avg=8.79,
                       Gn_avg=46.5,
                       Gn_dof=1,
                       Gg_avg=64.0,
                       Gg_dof=1000)

Ta_pair.add_spin_group(Jpi='4.0',
                       J_ID=2,
                       D_avg=4.99,
                       Gn_avg=35.5,
                       Gn_dof=1,
                       Gg_avg=64.0,
                       Gg_dof=1000)

### Experimental Models
cap1mm_exp_gen = Experimental_Model(title = "cap1",
                                reaction ="capture", 
                                energy_range = [200, 250],
                                n = (0.005631, 0),
                                FP = (45.27, 0.05),
                                burst= (8.0,1.0), 
                                temp= (294.2610, 0.0),
                                channel_widths={
                                    "maxE": [270], 
                                    "chw": [102.7],
                                    "dchw": [0.8]
                                }
                               )

trans1mm_exp_gen = Experimental_Model(title = "trans1",
                               reaction = "transmission", 
                               energy_range = [200,250],
                                n = (0.00566,0.0),  
                                FP = (100.14,0.0), 
                                burst = (8, 0.0), 
                                temp = (294.2610, 0.0),
                               channel_widths={
                                    "maxE": [216.16, 613.02], 
                                    "chw": [204.7, 102.4],
                                    "dchw": [1.6, 1.6]
                                }
                               )

sammy_rto = sammy_classes.SammyRunTimeOptions('/home/fire/SAMMY/sammy/build/install/bin/sammy',
                                        {"Print":   True,
                                         "bayes":   False,
                                         "keep_runDIR": False,
                                         "sammy_runDIR": "sammy_runDIR"
                                         })

template_creator.make_input_template('template_T.inp', Ta_pair, trans1mm_exp_gen, sammy_rto)
template_creator.make_input_template('template_Y.inp', Ta_pair, cap1mm_exp_gen, sammy_rto)

cap1mm_exp_gen.template = os.path.realpath('template_Y.inp')
trans1mm_exp_gen.template = os.path.realpath('template_T.inp')

### Measurement Models
cap1mm_meas_gen = Capture_Yield_RPI()
cap1mm_meas_red = Capture_Yield_RPI()

trans1mm_meas_gen = Transmission_RPI()
trans1mm_meas_red = Transmission_RPI()


### Syndat Models
options_cap1mm = syndatOPT(calculate_covariance=False)

syndat_cap1mm = Syndat_Model(cap1mm_exp_gen,
                            cap1mm_meas_gen,
                            cap1mm_meas_red,
                            options = options_cap1mm,
                            title='cap1mm')

options_trans1mm = syndatOPT(calculate_covariance = True)
syndat_trans1mm = Syndat_Model(trans1mm_exp_gen,
                            trans1mm_meas_gen,
                            trans1mm_meas_red,
                            options = options_trans1mm,
                            title='trans1mm')

# %%
### Control module for sampling from multiple syndat models

options_control = syndatOPT()
syndat = Syndat_Control(particle_pair= Ta_pair,
                        syndat_models= [syndat_trans1mm, syndat_cap1mm],
                        model_correlations=None,
                        options=options_control
                        )

syndat.sample(sammy_rto, num_samples=2)

# %%
### unpack sample and plot

sample1 = syndat.get_sample(1)

datasets = [sample1['cap1mm'].pw_reduced, sample1['trans1mm'].pw_reduced]#, transdat3, transdat6]
experiments= [cap1mm_exp_gen, trans1mm_exp_gen]#, exptrans3, exptrans6]
covariance_data = [sample1['cap1mm'].covariance_data, sample1['trans1mm'].covariance_data]

fig = plot_datafits(datasets, 
           experiments, 
           fits=[], 
           priors=[], 
           true=datasets, 
           true_pars=Ta_pair.resonance_ladder)
fig.tight_layout()

# saving true
fig.savefig(savefolder+'true.png',  dpi=dpi)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from ATARI.AutoFit.initial_FB_solve import InitialFB, InitialFBOPT

sammy_rto_fit = sammy_classes.SammyRunTimeOptions('/home/fire/SAMMY/sammy/build/install/bin/sammy',
                                        {"Print":   True,
                                         "bayes":   True,
                                         "keep_runDIR": True,
                                         "sammy_runDIR": "sammy_runDIR"
                                         })


options = InitialFBOPT(Gn_threshold=1e-1,
                       iterations=0)
autofit_initial = InitialFB(options)

# %%
outs = autofit_initial.fit(Ta_pair,
                               [200,250],
                               datasets,
                               experiments,
                               covariance_data,
                               sammy_rto_fit)
# Out:
# ========================================
# 	FIT 1
# ========================================
# Initial solve from 124 resonance features
#
# Stepping until convergence
# chi2 values
# step fudge: ['cap1', 'trans1', 'sum']
# 0    0.5  : [57.5923, 493.218, 550.8103]
# 1    0.75 : [22.8425, 62.0418, 84.8843]
# 2    1.125: [28.4162, 22.1042, 50.5204]
# Repeat step 3, 	fudge: ['cap1', 'trans1', 'sum']
# 		0.225: [35.9195, 30.7781, 66.6976]
# 		0.045: [21.5488, 14.3623, 35.9111]
# 3    0.045: [21.5488, 14.3623, 35.9111]
# 4    0.068: [15.0099, 8.8221, 23.832]
# 5    0.101: [11.3235, 6.0245, 17.348]
# 6    0.152: [9.513, 5.2286, 14.7416]
# 7    0.228: [8.4044, 5.3334, 13.7378]
# 8    0.342: [7.0531, 5.1897, 12.2428]
# 9    0.513: [6.8817, 5.0879, 11.9696]
# 10    0.769: [6.8924, 4.9138, 11.8061]
# 11    1.153: [6.7569, 4.9026, 11.6595]
# 12    1.73 : [6.668, 4.8863, 11.5542]
# 13    2.595: [6.5498, 4.9091, 11.4588]
# Chi2 improvement below threshold
#
# ----------------------------------------
# Eliminated 62.9% of resonance features based on neuton width
# Resolving with 46 resonance features
# ----------------------------------------
#
# Stepping until convergence
# chi2 values
# step fudge: ['cap1', 'trans1', 'sum']
# 0    0.5  : [6.634, 4.9781, 11.6121]
# Repeat step 1, 	fudge: ['cap1', 'trans1', 'sum']
# 		0.1  : [6.6428, 4.9699, 11.6128]
# 		0.02 : [6.6685, 4.9375, 11.606]
# 1    0.02 : [6.6685, 4.9375, 11.606]
# Chi2 improvement below threshold
#
# Complete after no neutron width features below threshold
#
# ========================================
# 	FIT 2
# ========================================
# Initial solve from 46 resonance features
#
# Stepping until convergence
# chi2 values
# step fudge: ['cap1', 'trans1', 'sum']
# 0    0.5  : [6.6684, 4.9375, 11.606]
# 1    0.75 : [2.6422, 2.3131, 4.9553]
# 2    1.125: [1.9745, 2.0829, 4.0574]
# 3    1.688: [1.887, 2.0407, 3.9277]
# 4    2.531: [1.8208, 2.0552, 3.876]
# Repeat step 5, 	fudge: ['cap1', 'trans1', 'sum']
# 		0.506: [2.9262, 2.0819, 5.0082]
# 		0.101: [1.8204, 2.0615, 3.8819]
# 		0.02 : [1.9511, 2.0628, 4.0139]
# 		0.004: [1.9144, 2.0734, 3.9878]
# 		0.001: [2.0221, 2.0925, 4.1146]
# 		0.0  : [1.9454, 2.0813, 4.0267]
# 		0.0  : [2.022, 2.0932, 4.1152]
# 		0.0  : [1.9524, 2.0857, 4.0382]
# 5    0.0  : [1.9524, 2.0857, 4.0382]
# Fudge below minimum value, taking solution 4
#
# ----------------------------------------
# Eliminated 13.04% of resonance features based on neuton width
# Resolving with 40 resonance features
# ----------------------------------------
#
# Stepping until convergence
# chi2 values
# step fudge: ['cap1', 'trans1', 'sum']
# 0    0.5  : [1.8347, 2.0533, 3.888]
# 1    0.75 : [1.7835, 2.0298, 3.8133]
# 2    1.125: [1.7749, 2.0277, 3.8026]
# 3    1.688: [1.7644, 2.0267, 3.7911]
# Repeat step 4, 	fudge: ['cap1', 'trans1', 'sum']
# 		0.338: [1.8384, 2.0216, 3.86]
# 		0.068: [1.8116, 2.0305, 3.8421]
# 		0.014: [1.8418, 2.0309, 3.8727]
# 		0.003: [1.825, 2.026, 3.851]
# 		0.001: [1.8522, 2.0314, 3.8836]
# 		0.0  : [1.8556, 2.025, 3.8805]
# 		0.0  : [1.8689, 2.033, 3.9019]
# 		0.0  : [1.8776, 2.0255, 3.9031]
# 4    0.0  : [1.8776, 2.0255, 3.9031]
# Fudge below minimum value, taking solution 3
#
# Complete after no neutron width features below threshold

# %%
final_fb_output = outs[-1]
len(final_fb_output.par_post)
# Out:
# 40

# %%
final_fb_output.pw_post[0]
# Out:
#               E    exp_xs  exp_xs_unc   theo_xs  theo_xs_bayes  exp_trans  \
# 0    200.176298 -0.007484    0.019445  0.027614            NaN        NaN
# 1    200.354155  0.040300    0.011665  0.025789            NaN        NaN
# 2    200.532249  0.013158    0.010475  0.015629            NaN        NaN
# 3    200.710580 -0.009191    0.009197  0.007389            NaN        NaN
# 4    200.889150  0.020484    0.010721  0.004296            NaN        NaN
# ..          ...       ...         ...       ...            ...        ...
# 232  248.785641  0.094488    0.016159  0.081700            NaN        NaN
# 233  249.032087  0.081344    0.012819  0.071589            NaN        NaN
# 234  249.278900  0.053866    0.014684  0.057243            NaN        NaN
# 235  249.526080  0.037138    0.017500  0.049835            NaN        NaN
# 236  249.773628  0.014860    0.018692  0.046485            NaN        NaN
#
#      exp_trans_unc  theo_trans  theo_trans_bayes
# 0              NaN         NaN               NaN
# 1              NaN         NaN               NaN
# 2              NaN         NaN               NaN
# 3              NaN         NaN               NaN
# 4              NaN         NaN               NaN
# ..             ...         ...               ...
# 232            NaN         NaN               NaN
# 233            NaN         NaN               NaN
# 234            NaN         NaN               NaN
# 235            NaN         NaN               NaN
# 236            NaN         NaN               NaN
#
# [237 rows x 9 columns]

# %%
# fig = plot(datasets, experiments, fits=final_fb_output.pw_post, priors=[], true=datasets)
# ax = fig.get_axes()
# # ax[1].plot(final_fb_output.pw_post[0].E,np.flipud(final_fb_output.pw_post[0].theo_xs), 'k')

# # fig.tight_layout()

fig = plot_datafits(datasets, experiments, 
           fits=final_fb_output.pw_post, fits_chi2=final_fb_output.chi2_post,
           priors=[], 
           true=datasets,
true_pars = Ta_pair.resonance_ladder,
fit_pars = final_fb_output.par_post
)
fig.tight_layout()
# saving 
fig.savefig(savefolder+'initial.png', dpi=dpi)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# initial characterization of the fit
init_chars_dict = elim_addit_funcs.characterize_sol(Ta_pair,
                     datasets,
                     experiments,
                     final_fb_output,
                     covariance_data = covariance_data
                     )
print(init_chars_dict)
print(sum(init_chars_dict['chi2_stat']))
# Out:
# Warning - using precalculated chi2 value
# Using cov data for chi2 calc
# Warning - using precalculated chi2 value
# Using cov data for chi2 calc
# {'aic': [658.1659999999999, 1117.5549999999998], 'aicc': [908.5108275862068, 1210.631923076923], 'bic': [1074.3332169362159, 1606.0435273602989], 'bicc': [1416.5583602520871, 1747.3049244926644], 'chi2_stat': [418.166, 877.555], 'NLLW': {'3.0': 79.0807087353554, '4.0': 37.00101206769726}}
# 1295.721

# %%
# Elimination example

import importlib
importlib.reload(chi2_eliminator_v2)
importlib.reload(elim_addit_funcs)

start_ladder = final_fb_output.par_post
assert isinstance(start_ladder, pd.DataFrame)

# side resonances if needed, otherways - keep empty
side_resonances_df = pd.DataFrame()

# %%
# # if we do not want to wait hours...

# N = 20

# # just to reduce processing time
# start_ladder = elim_addit_funcs.reduce_ladder(ladder_df=start_ladder,
#                              Gn1_threshold=0.1,
#                              vary_list=[1,1,1],
#                              N=N,
#                              keep_fixed=True,
#                              fixed_side_resonances=side_resonances_df)

# start_ladder

# %%
# defining rto & inputs
elim_sammyINPyw = sammy_classes.SammyInputDataYW(
    particle_pair = Ta_pair,
    resonance_ladder = start_ladder,

    datasets = datasets,
    experimental_covariance=covariance_data,
    experiments = experiments,

    max_steps = 0,
    iterations = 2,
    step_threshold = 0.01,
    autoelim_threshold = None,

    LS = False,
    LevMar = True,
    LevMarV = 1.5,

    minF = 1e-5,
    maxF = 10,
    initial_parameter_uncertainty = 0.05
    )

# defining the elim_opts
elim_opts = chi2_eliminator_v2.elim_OPTs(chi2_allowed = 28,
                                         stop_at_chi2_thr = False,
                                      fixed_resonances_df = side_resonances_df,
                                      deep_fit_max_iter = 20,
                                      deep_fit_step_thr = 0.01,
                                      start_fudge_for_deep_stage = 0.05,
                                      )

# %%
elimi = chi2_eliminator_v2.eliminator_by_chi2(rto=sammy_rto_fit,
                                            sammyINPyw = elim_sammyINPyw , 
                                            options = elim_opts
                            )

# %%
# true chi2
true_chars = elimi.evaluate_prior(Ta_pair.resonance_ladder) 
print(true_chars.chi2)
# Out:
# [726.705, 923.862]

# %%
hist = elimi.eliminate(ladder_df= start_ladder)# final_fb_output.par_post
# Out:
# ****************************************
# Elimination cycle printout enabled
# ****************************************
#
# Chi2 thresold applied for model selection: 28
#
#
# Input ladder:
#              E          Gg         Gn1  varyE  varyGg  varyGn1  J_ID
# 0   200.236284   51.081415    0.144070    1.0     1.0      1.0   1.0
# 1   202.611598   46.107975    0.210388    1.0     1.0      1.0   1.0
# 2   204.808973   64.363475   76.293951    1.0     1.0      1.0   1.0
# 3   212.341997   11.815223    3.142673    1.0     1.0      1.0   1.0
# 4   213.356652   46.169777   56.833616    1.0     1.0      1.0   1.0
# 5   216.578789   24.666592    0.223826    1.0     1.0      1.0   1.0
# 6   219.326684   58.106186   11.947380    1.0     1.0      1.0   1.0
# 7   221.559970   48.608579    0.285675    1.0     1.0      1.0   1.0
# 8   221.557688   58.490034    0.131624    1.0     1.0      1.0   1.0
# 9   223.776780   11.511978    0.468516    1.0     1.0      1.0   1.0
# 10  226.602771   22.677167    0.406262    1.0     1.0      1.0   1.0
# 11  229.386997   69.044669   26.883803    1.0     1.0      1.0   1.0
# 12  232.547213   28.629198    0.284037    1.0     1.0      1.0   1.0
# 13  234.556662  105.173061  135.069462    1.0     1.0      1.0   1.0
# 14  236.783550   60.451852    0.336449    1.0     1.0      1.0   1.0
# 15  238.428410   51.176651    0.478412    1.0     1.0      1.0   1.0
# 16  241.185125   43.248329    0.559211    1.0     1.0      1.0   1.0
# 17  242.683030   52.202944    0.231676    1.0     1.0      1.0   1.0
# 18  243.321134   66.857571    0.147991    1.0     1.0      1.0   1.0
# 19  245.248499   68.699498  213.632656    1.0     1.0      1.0   1.0
# 20  246.100774   66.706910   83.966735    1.0     1.0      1.0   1.0
# 21  246.618639   66.385406    0.125701    1.0     1.0      1.0   1.0
# 22  248.804101   48.369042    0.485415    1.0     1.0      1.0   1.0
# 23  200.236930   41.332686    0.152413    1.0     1.0      1.0   2.0
# 24  202.633701   37.401422    0.253947    1.0     1.0      1.0   2.0
# 25  203.767572   25.062147    0.420571    1.0     1.0      1.0   2.0
# 26  213.021383   40.667936    4.085500    1.0     1.0      1.0   2.0
# 27  213.394050   44.138169   17.276807    1.0     1.0      1.0   2.0
# 28  216.637840   13.740468    0.443920    1.0     1.0      1.0   2.0
# 29  219.207210   95.212083    1.661404    1.0     1.0      1.0   2.0
# 30  221.572712    7.164831    1.549064    1.0     1.0      1.0   2.0
# 31  223.729373   13.636171    0.270985    1.0     1.0      1.0   2.0
# 32  226.543004   23.946280    0.268355    1.0     1.0      1.0   2.0
# 33  229.292794   39.695564    0.214971    1.0     1.0      1.0   2.0
# 34  235.195224    0.098166   10.427630    1.0     1.0      1.0   2.0
# 35  237.252857   42.208938    0.517471    1.0     1.0      1.0   2.0
# 36  238.578276   76.592792   11.871784    1.0     1.0      1.0   2.0
# 37  241.183618   41.869788    0.434821    1.0     1.0      1.0   2.0
# 38  242.698702   62.107392   14.291012    1.0     1.0      1.0   2.0
# 39  246.487979   60.289258    0.431775    1.0     1.0      1.0   2.0
# Side resonances used:
# Empty DataFrame
# Columns: []
# Index: []
#
# Stopping option:
# 	 stop_at_chi2_thr: False
# ****************************************
# Current level: 40
# 	 Searching for models with 39 resonances...
# ****************************************
#
#
# 	 init_sol_level_40
# 	 [418.167, 877.556]
#
# Prior ladder check, deleted 0, E_λ  = 200.2362844
# 		Σχ²: 	 1297.161 | 	 base: 1295.723
# 		1.438		<=		28		=>		✓
#
# Prior ladder check, deleted 1, E_λ  = 202.6115976
# 		Σχ²: 	 1303.288 | 	 base: 1295.723
# 		7.565		<=		28		=>		✓
#
# Prior ladder check, deleted 2, E_λ  = 204.8089731
# 		Σχ²: 	 31176.49 | 	 base: 1295.723
# 		29880.767		>		28		=>		✗
#
# Prior ladder check, deleted 3, E_λ  = 212.341997
# 		Σχ²: 	 1483.315 | 	 base: 1295.723
# 		187.592		>		28		=>		✗
#
# Prior ladder check, deleted 4, E_λ  = 213.3566519
# 		Σχ²: 	 3677.362 | 	 base: 1295.723
# 		2381.639		>		28		=>		✗
#
# Prior ladder check, deleted 5, E_λ  = 216.5787894
# 		Σχ²: 	 1298.946 | 	 base: 1295.723
# 		3.223		<=		28		=>		✓
#
# Prior ladder check, deleted 6, E_λ  = 219.3266845
# 		Σχ²: 	 2539.4 | 	 base: 1295.723
# 		1243.677		>		28		=>		✗
#
# Prior ladder check, deleted 7, E_λ  = 221.5599696
# 		Σχ²: 	 1301.061 | 	 base: 1295.723
# 		5.338		<=		28		=>		✓
#
# Prior ladder check, deleted 8, E_λ  = 221.5576883
# 		Σχ²: 	 1297.259 | 	 base: 1295.723
# 		1.536		<=		28		=>		✓
#
# Prior ladder check, deleted 9, E_λ  = 223.7767804
# 		Σχ²: 	 1312.477 | 	 base: 1295.723
# 		16.754		<=		28		=>		✓
#
# Prior ladder check, deleted 10, E_λ  = 226.6027707
# 		Σχ²: 	 1308.797 | 	 base: 1295.723
# 		13.074		<=		28		=>		✓
#
# Prior ladder check, deleted 11, E_λ  = 229.3869972
# 		Σχ²: 	 5569.91 | 	 base: 1295.723
# 		4274.187		>		28		=>		✗
#
# Prior ladder check, deleted 12, E_λ  = 232.5472127
# 		Σχ²: 	 1299.744 | 	 base: 1295.723
# 		4.021		<=		28		=>		✓
#
# Prior ladder check, deleted 13, E_λ  = 234.5566625
# 		Σχ²: 	 37247.18 | 	 base: 1295.723
# 		35951.457		>		28		=>		✗
#
# Prior ladder check, deleted 14, E_λ  = 236.7835505
# 		Σχ²: 	 1298.491 | 	 base: 1295.723
# 		2.768		<=		28		=>		✓
#
# Prior ladder check, deleted 15, E_λ  = 238.4284103
# 		Σχ²: 	 1297.271 | 	 base: 1295.723
# 		1.548		<=		28		=>		✓
#
# Prior ladder check, deleted 16, E_λ  = 241.1851247
# 		Σχ²: 	 1309.903 | 	 base: 1295.723
# 		14.18		<=		28		=>		✓
#
# Prior ladder check, deleted 17, E_λ  = 242.6830295
# 		Σχ²: 	 1296.088 | 	 base: 1295.723
# 		0.365		<=		28		=>		✓
#
# Prior ladder check, deleted 18, E_λ  = 243.3211335
# 		Σχ²: 	 1296.003 | 	 base: 1295.723
# 		0.28		<=		28		=>		✓
#
# Prior ladder check, deleted 19, E_λ  = 245.2484994
# 		Σχ²: 	 54382.84 | 	 base: 1295.723
# 		53087.117		>		28		=>		✗
#
# Prior ladder check, deleted 20, E_λ  = 246.1007741
# 		Σχ²: 	 6164.153 | 	 base: 1295.723
# 		4868.43		>		28		=>		✗
#
# Prior ladder check, deleted 21, E_λ  = 246.6186393
# 		Σχ²: 	 1295.752 | 	 base: 1295.723
# 		0.029		<=		28		=>		✓
#
# Prior ladder check, deleted 22, E_λ  = 248.8041009
# 		Σχ²: 	 1302.486 | 	 base: 1295.723
# 		6.763		<=		28		=>		✓
#
# Prior ladder check, deleted 23, E_λ  = 200.2369297
# 		Σχ²: 	 1298.444 | 	 base: 1295.723
# 		2.721		<=		28		=>		✓
#
# Prior ladder check, deleted 24, E_λ  = 202.6337014
# 		Σχ²: 	 1314.504 | 	 base: 1295.723
# 		18.781		<=		28		=>		✓
#
# Prior ladder check, deleted 25, E_λ  = 203.7675719
# 		Σχ²: 	 1318.643 | 	 base: 1295.723
# 		22.92		<=		28		=>		✓
#
# Prior ladder check, deleted 26, E_λ  = 213.021383
# 		Σχ²: 	 1351.942 | 	 base: 1295.723
# 		56.219		>		28		=>		✗
#
# Prior ladder check, deleted 27, E_λ  = 213.3940498
# 		Σχ²: 	 1459.882 | 	 base: 1295.723
# 		164.159		>		28		=>		✗
#
# Prior ladder check, deleted 28, E_λ  = 216.6378399
# 		Σχ²: 	 1314.854 | 	 base: 1295.723
# 		19.131		<=		28		=>		✓
#
# Prior ladder check, deleted 29, E_λ  = 219.2072095
# 		Σχ²: 	 1325.418 | 	 base: 1295.723
# 		29.695		>		28		=>		✗
#
# Prior ladder check, deleted 30, E_λ  = 221.572712
# 		Σχ²: 	 1460.582 | 	 base: 1295.723
# 		164.859		>		28		=>		✗
#
# Prior ladder check, deleted 31, E_λ  = 223.7293734
# 		Σχ²: 	 1305.469 | 	 base: 1295.723
# 		9.746		<=		28		=>		✓
#
# Prior ladder check, deleted 32, E_λ  = 226.5430044
# 		Σχ²: 	 1305.681 | 	 base: 1295.723
# 		9.958		<=		28		=>		✓
#
# Prior ladder check, deleted 33, E_λ  = 229.2927939
# 		Σχ²: 	 1296.901 | 	 base: 1295.723
# 		1.178		<=		28		=>		✓
#
# Prior ladder check, deleted 34, E_λ  = 235.1952243
# 		Σχ²: 	 1529.72 | 	 base: 1295.723
# 		233.997		>		28		=>		✗
#
# Prior ladder check, deleted 35, E_λ  = 237.2528571
# 		Σχ²: 	 1305.678 | 	 base: 1295.723
# 		9.955		<=		28		=>		✓
#
# Prior ladder check, deleted 36, E_λ  = 238.5782762
# 		Σχ²: 	 3016.05 | 	 base: 1295.723
# 		1720.327		>		28		=>		✗
#
# Prior ladder check, deleted 37, E_λ  = 241.1836181
# 		Σχ²: 	 1310.045 | 	 base: 1295.723
# 		14.322		<=		28		=>		✓
#
# Prior ladder check, deleted 38, E_λ  = 242.6987025
# 		Σχ²: 	 3598.06 | 	 base: 1295.723
# 		2302.337		>		28		=>		✗
#
# Prior ladder check, deleted 39, E_λ  = 246.4879794
# 		Σχ²: 	 1295.558 | 	 base: 1295.723
# 		-0.165		<=		28		=>		✓
#
#
# Priors passed the test...25
# Best model found 39:
# Σχ²: 	 1295.558
#
#
# Starting "deep" fitting of best initial guess by chi2...
#
# 	 proc_time 42.196887731552124  s
#
# 	 Benefit in chi2: -0.16499999999996362, while initial benefit for 20 iter. was -0.16499999999996362
# Deep fitting decision about model selection:
#
# 	 Before: 1295.558
# 	 After: 1295.558
#
# Deep fitting stage. Results
#              E         Gn1          Gg  varyE  varyGg  varyGn1  J_ID
# 0   200.236284    0.144070   51.081415    1.0     1.0      1.0   1.0
# 1   202.611598    0.210388   46.107975    1.0     1.0      1.0   1.0
# 2   204.808973   76.293951   64.363475    1.0     1.0      1.0   1.0
# 3   212.341997    3.142673   11.815223    1.0     1.0      1.0   1.0
# 4   213.356652   56.833616   46.169777    1.0     1.0      1.0   1.0
# 5   216.578789    0.223826   24.666592    1.0     1.0      1.0   1.0
# 6   219.326684   11.947380   58.106186    1.0     1.0      1.0   1.0
# 7   221.559970    0.285675   48.608579    1.0     1.0      1.0   1.0
# 8   221.557688    0.131624   58.490034    1.0     1.0      1.0   1.0
# 9   223.776780    0.468516   11.511978    1.0     1.0      1.0   1.0
# 10  226.602771    0.406262   22.677167    1.0     1.0      1.0   1.0
# 11  229.386997   26.883803   69.044669    1.0     1.0      1.0   1.0
# 12  232.547213    0.284037   28.629198    1.0     1.0      1.0   1.0
# 13  234.556662  135.069462  105.173061    1.0     1.0      1.0   1.0
# 14  236.783550    0.336449   60.451852    1.0     1.0      1.0   1.0
# 15  238.428410    0.478412   51.176651    1.0     1.0      1.0   1.0
# 16  241.185125    0.559211   43.248329    1.0     1.0      1.0   1.0
# 17  242.683030    0.231676   52.202944    1.0     1.0      1.0   1.0
# 18  243.321134    0.147991   66.857571    1.0     1.0      1.0   1.0
# 19  245.248499  213.632656   68.699498    1.0     1.0      1.0   1.0
# 20  246.100774   83.966735   66.706910    1.0     1.0      1.0   1.0
# 21  246.618639    0.125701   66.385406    1.0     1.0      1.0   1.0
# 22  248.804101    0.485415   48.369042    1.0     1.0      1.0   1.0
# 23  200.236930    0.152413   41.332686    1.0     1.0      1.0   2.0
# 24  202.633701    0.253947   37.401422    1.0     1.0      1.0   2.0
# 25  203.767572    0.420571   25.062147    1.0     1.0      1.0   2.0
# 26  213.021383    4.085500   40.667936    1.0     1.0      1.0   2.0
# 27  213.394050   17.276807   44.138169    1.0     1.0      1.0   2.0
# 28  216.637840    0.443920   13.740468    1.0     1.0      1.0   2.0
# 29  219.207210    1.661404   95.212083    1.0     1.0      1.0   2.0
# 30  221.572712    1.549064    7.164831    1.0     1.0      1.0   2.0
# 31  223.729373    0.270985   13.636171    1.0     1.0      1.0   2.0
# 32  226.543004    0.268355   23.946280    1.0     1.0      1.0   2.0
# 33  229.292794    0.214971   39.695564    1.0     1.0      1.0   2.0
# 34  235.195224   10.427630    0.098166    1.0     1.0      1.0   2.0
# 35  237.252857    0.517471   42.208938    1.0     1.0      1.0   2.0
# 36  238.578276   11.871784   76.592792    1.0     1.0      1.0   2.0
# 37  241.183618    0.434821   41.869788    1.0     1.0      1.0   2.0
# 38  242.698702   14.291012   62.107392    1.0     1.0      1.0   2.0
#
# Current N_res: 39
# Level 40 passed the test: True
# End of deep fitting stage...
#
#
# Level time: 55.3 sec
# Total elapsed time: 55.3 sec
# time per res.: 55.3 sec
#
#
# ****************************************
#
# Skipping stopping by chi2 test, going to 1 res model
# ****************************************
# Current level: 39
# 	 Searching for models with 38 resonances...
# ****************************************
#
#
# 	 init_sol_level_39
# 	 [418.466, 877.092]
#
# Prior ladder check, deleted 0, E_λ  = 200.236284
# 		Σχ²: 	 1296.992 | 	 base: 1295.558
# 		1.434		<=		28		=>		✓
#
# Prior ladder check, deleted 1, E_λ  = 202.611598
# 		Σχ²: 	 1303.116 | 	 base: 1295.558
# 		7.558		<=		28		=>		✓
#
# Prior ladder check, deleted 2, E_λ  = 204.808973
# 		Σχ²: 	 31173.94 | 	 base: 1295.558
# 		29878.382		>		28		=>		✗
#
# Prior ladder check, deleted 3, E_λ  = 212.341997
# 		Σχ²: 	 1483.055 | 	 base: 1295.558
# 		187.497		>		28		=>		✗
#
# Prior ladder check, deleted 4, E_λ  = 213.356652
# 		Σχ²: 	 3676.677 | 	 base: 1295.558
# 		2381.119		>		28		=>		✗
#
# Prior ladder check, deleted 5, E_λ  = 216.578789
# 		Σχ²: 	 1298.773 | 	 base: 1295.558
# 		3.215		<=		28		=>		✓
#
# Prior ladder check, deleted 6, E_λ  = 219.326684
# 		Σχ²: 	 2538.9 | 	 base: 1295.558
# 		1243.342		>		28		=>		✗
#
# Prior ladder check, deleted 7, E_λ  = 221.55997
# 		Σχ²: 	 1300.886 | 	 base: 1295.558
# 		5.328		<=		28		=>		✓
#
# Prior ladder check, deleted 8, E_λ  = 221.557688
# 		Σχ²: 	 1297.09 | 	 base: 1295.558
# 		1.532		<=		28		=>		✓
#
# Prior ladder check, deleted 9, E_λ  = 223.77678
# 		Σχ²: 	 1312.296 | 	 base: 1295.558
# 		16.738		<=		28		=>		✓
#
# Prior ladder check, deleted 10, E_λ  = 226.602771
# 		Σχ²: 	 1308.62 | 	 base: 1295.558
# 		13.062		<=		28		=>		✓
#
# Prior ladder check, deleted 11, E_λ  = 229.386997
# 		Σχ²: 	 5569.02 | 	 base: 1295.558
# 		4273.462		>		28		=>		✗
#
# Prior ladder check, deleted 12, E_λ  = 232.547213
# 		Σχ²: 	 1299.57 | 	 base: 1295.558
# 		4.012		<=		28		=>		✓
#
# Prior ladder check, deleted 13, E_λ  = 234.556662
# 		Σχ²: 	 37244.62 | 	 base: 1295.558
# 		35949.062		>		28		=>		✗
#
# Prior ladder check, deleted 14, E_λ  = 236.78355
# 		Σχ²: 	 1298.319 | 	 base: 1295.558
# 		2.761		<=		28		=>		✓
#
# Prior ladder check, deleted 15, E_λ  = 238.42841
# 		Σχ²: 	 1297.106 | 	 base: 1295.558
# 		1.548		<=		28		=>		✓
#
# Prior ladder check, deleted 16, E_λ  = 241.185125
# 		Σχ²: 	 1309.867 | 	 base: 1295.558
# 		14.309		<=		28		=>		✓
#
# Prior ladder check, deleted 17, E_λ  = 242.68303
# 		Σχ²: 	 1295.968 | 	 base: 1295.558
# 		0.41		<=		28		=>		✓
#
# Prior ladder check, deleted 18, E_λ  = 243.321134
# 		Σχ²: 	 1295.849 | 	 base: 1295.558
# 		0.291		<=		28		=>		✓
#
# Prior ladder check, deleted 19, E_λ  = 245.248499
# 		Σχ²: 	 54427.39 | 	 base: 1295.558
# 		53131.832		>		28		=>		✗
#
# Prior ladder check, deleted 20, E_λ  = 246.100774
# 		Σχ²: 	 6421.141 | 	 base: 1295.558
# 		5125.583		>		28		=>		✗
#
# Prior ladder check, deleted 21, E_λ  = 246.618639
# 		Σχ²: 	 1295.842 | 	 base: 1295.558
# 		0.284		<=		28		=>		✓
#
# Prior ladder check, deleted 22, E_λ  = 248.804101
# 		Σχ²: 	 1302.612 | 	 base: 1295.558
# 		7.054		<=		28		=>		✓
#
# Prior ladder check, deleted 23, E_λ  = 200.23693
# 		Σχ²: 	 1298.272 | 	 base: 1295.558
# 		2.714		<=		28		=>		✓
#
# Prior ladder check, deleted 24, E_λ  = 202.633701
# 		Σχ²: 	 1314.327 | 	 base: 1295.558
# 		18.769		<=		28		=>		✓
#
# Prior ladder check, deleted 25, E_λ  = 203.767572
# 		Σχ²: 	 1318.458 | 	 base: 1295.558
# 		22.9		<=		28		=>		✓
#
# Prior ladder check, deleted 26, E_λ  = 213.021383
# 		Σχ²: 	 1351.713 | 	 base: 1295.558
# 		56.155		>		28		=>		✗
#
# Prior ladder check, deleted 27, E_λ  = 213.39405
# 		Σχ²: 	 1459.573 | 	 base: 1295.558
# 		164.015		>		28		=>		✗
#
# Prior ladder check, deleted 28, E_λ  = 216.63784
# 		Σχ²: 	 1314.667 | 	 base: 1295.558
# 		19.109		<=		28		=>		✓
#
# Prior ladder check, deleted 29, E_λ  = 219.20721
# 		Σχ²: 	 1325.2 | 	 base: 1295.558
# 		29.642		>		28		=>		✗
#
# Prior ladder check, deleted 30, E_λ  = 221.572712
# 		Σχ²: 	 1460.342 | 	 base: 1295.558
# 		164.784		>		28		=>		✗
#
# Prior ladder check, deleted 31, E_λ  = 223.729373
# 		Σχ²: 	 1305.291 | 	 base: 1295.558
# 		9.733		<=		28		=>		✓
#
# Prior ladder check, deleted 32, E_λ  = 226.543004
# 		Σχ²: 	 1305.504 | 	 base: 1295.558
# 		9.946		<=		28		=>		✓
#
# Prior ladder check, deleted 33, E_λ  = 229.292794
# 		Σχ²: 	 1296.731 | 	 base: 1295.558
# 		1.173		<=		28		=>		✓
#
# Prior ladder check, deleted 34, E_λ  = 235.195224
# 		Σχ²: 	 1529.359 | 	 base: 1295.558
# 		233.801		>		28		=>		✗
#
# Prior ladder check, deleted 35, E_λ  = 237.252857
# 		Σχ²: 	 1305.494 | 	 base: 1295.558
# 		9.936		<=		28		=>		✓
#
# Prior ladder check, deleted 36, E_λ  = 238.578276
# 		Σχ²: 	 3015.64 | 	 base: 1295.558
# 		1720.082		>		28		=>		✗
#
# Prior ladder check, deleted 37, E_λ  = 241.183618
# 		Σχ²: 	 1309.998 | 	 base: 1295.558
# 		14.44		<=		28		=>		✓
#
# Prior ladder check, deleted 38, E_λ  = 242.698702
# 		Σχ²: 	 3601.59 | 	 base: 1295.558
# 		2306.032		>		28		=>		✗
#
#
# Priors passed the test...24
# Best model found 21:
# Σχ²: 	 1295.842
#
#
# Starting "deep" fitting of best initial guess by chi2...
#
# 	 proc_time 39.85571050643921  s
#
# 	 Benefit in chi2: 0.2840000000001055, while initial benefit for 20 iter. was 0.2840000000001055
# Deep fitting decision about model selection:
#
# 	 Before: 1295.842
# 	 After: 1295.842
#
# Deep fitting stage. Results
#              E         Gn1          Gg  varyE  varyGg  varyGn1  J_ID
# 0   200.236284    0.144070   51.081415    1.0     1.0      1.0   1.0
# 1   202.611598    0.210388   46.107975    1.0     1.0      1.0   1.0
# 2   204.808973   76.293951   64.363475    1.0     1.0      1.0   1.0
# 3   212.341997    3.142673   11.815223    1.0     1.0      1.0   1.0
# 4   213.356652   56.833616   46.169777    1.0     1.0      1.0   1.0
# 5   216.578789    0.223826   24.666592    1.0     1.0      1.0   1.0
# 6   219.326684   11.947380   58.106186    1.0     1.0      1.0   1.0
# 7   221.559970    0.285675   48.608579    1.0     1.0      1.0   1.0
# 8   221.557688    0.131624   58.490034    1.0     1.0      1.0   1.0
# 9   223.776780    0.468516   11.511978    1.0     1.0      1.0   1.0
# 10  226.602771    0.406262   22.677167    1.0     1.0      1.0   1.0
# 11  229.386997   26.883803   69.044669    1.0     1.0      1.0   1.0
# 12  232.547213    0.284037   28.629198    1.0     1.0      1.0   1.0
# 13  234.556662  135.069462  105.173061    1.0     1.0      1.0   1.0
# 14  236.783550    0.336449   60.451852    1.0     1.0      1.0   1.0
# 15  238.428410    0.478412   51.176651    1.0     1.0      1.0   1.0
# 16  241.185125    0.559211   43.248329    1.0     1.0      1.0   1.0
# 17  242.683030    0.231676   52.202944    1.0     1.0      1.0   1.0
# 18  243.321134    0.147991   66.857571    1.0     1.0      1.0   1.0
# 19  245.248499  213.632656   68.699498    1.0     1.0      1.0   1.0
# 20  246.100774   83.966735   66.706910    1.0     1.0      1.0   1.0
# 21  248.804101    0.485415   48.369042    1.0     1.0      1.0   1.0
# 22  200.236930    0.152413   41.332686    1.0     1.0      1.0   2.0
# 23  202.633701    0.253947   37.401422    1.0     1.0      1.0   2.0
# 24  203.767572    0.420571   25.062147    1.0     1.0      1.0   2.0
# 25  213.021383    4.085500   40.667936    1.0     1.0      1.0   2.0
# 26  213.394050   17.276807   44.138169    1.0     1.0      1.0   2.0
# 27  216.637840    0.443920   13.740468    1.0     1.0      1.0   2.0
# 28  219.207210    1.661404   95.212083    1.0     1.0      1.0   2.0
# 29  221.572712    1.549064    7.164831    1.0     1.0      1.0   2.0
# 30  223.729373    0.270985   13.636171    1.0     1.0      1.0   2.0
# 31  226.543004    0.268355   23.946280    1.0     1.0      1.0   2.0
# 32  229.292794    0.214971   39.695564    1.0     1.0      1.0   2.0
# 33  235.195224   10.427630    0.098166    1.0     1.0      1.0   2.0
# 34  237.252857    0.517471   42.208938    1.0     1.0      1.0   2.0
# 35  238.578276   11.871784   76.592792    1.0     1.0      1.0   2.0
# 36  241.183618    0.434821   41.869788    1.0     1.0      1.0   2.0
# 37  242.698702   14.291012   62.107392    1.0     1.0      1.0   2.0
#
# Current N_res: 38
# Level 39 passed the test: True
# End of deep fitting stage...
#
#
# Level time: 51.7 sec
# Total elapsed time: 107.0 sec
# time per res.: 53.5 sec
#
#
# ****************************************
#
# Skipping stopping by chi2 test, going to 1 res model
# ****************************************
# Current level: 38
# 	 Searching for models with 37 resonances...
# ****************************************
#
#
# 	 init_sol_level_38
# 	 [418.573, 877.269]
#
# Prior ladder check, deleted 0, E_λ  = 200.236284
# 		Σχ²: 	 1297.274 | 	 base: 1295.842
# 		1.432		<=		28		=>		✓
#
# Prior ladder check, deleted 1, E_λ  = 202.611598
# 		Σχ²: 	 1303.397 | 	 base: 1295.842
# 		7.555		<=		28		=>		✓
#
# Prior ladder check, deleted 2, E_λ  = 204.808973
# 		Σχ²: 	 31173.36 | 	 base: 1295.842
# 		29877.518		>		28		=>		✗
#
# Prior ladder check, deleted 3, E_λ  = 212.341997
# 		Σχ²: 	 1483.292 | 	 base: 1295.842
# 		187.45		>		28		=>		✗
#
# Prior ladder check, deleted 4, E_λ  = 213.356652
# 		Σχ²: 	 3676.718 | 	 base: 1295.842
# 		2380.876		>		28		=>		✗
#
# Prior ladder check, deleted 5, E_λ  = 216.578789
# 		Σχ²: 	 1299.054 | 	 base: 1295.842
# 		3.212		<=		28		=>		✓
#
# Prior ladder check, deleted 6, E_λ  = 219.326684
# 		Σχ²: 	 2539.04 | 	 base: 1295.842
# 		1243.198		>		28		=>		✗
#
# Prior ladder check, deleted 7, E_λ  = 221.55997
# 		Σχ²: 	 1301.167 | 	 base: 1295.842
# 		5.325		<=		28		=>		✓
#
# Prior ladder check, deleted 8, E_λ  = 221.557688
# 		Σχ²: 	 1297.372 | 	 base: 1295.842
# 		1.53		<=		28		=>		✓
#
# Prior ladder check, deleted 9, E_λ  = 223.77678
# 		Σχ²: 	 1312.574 | 	 base: 1295.842
# 		16.732		<=		28		=>		✓
#
# Prior ladder check, deleted 10, E_λ  = 226.602771
# 		Σχ²: 	 1308.9 | 	 base: 1295.842
# 		13.058		<=		28		=>		✓
#
# Prior ladder check, deleted 11, E_λ  = 229.386997
# 		Σχ²: 	 5569.05 | 	 base: 1295.842
# 		4273.208		>		28		=>		✗
#
# Prior ladder check, deleted 12, E_λ  = 232.547213
# 		Σχ²: 	 1299.852 | 	 base: 1295.842
# 		4.01		<=		28		=>		✓
#
# Prior ladder check, deleted 13, E_λ  = 234.556662
# 		Σχ²: 	 37244.07 | 	 base: 1295.842
# 		35948.228		>		28		=>		✗
#
# Prior ladder check, deleted 14, E_λ  = 236.78355
# 		Σχ²: 	 1298.599 | 	 base: 1295.842
# 		2.757		<=		28		=>		✓
#
# Prior ladder check, deleted 15, E_λ  = 238.42841
# 		Σχ²: 	 1297.391 | 	 base: 1295.842
# 		1.549		<=		28		=>		✓
#
# Prior ladder check, deleted 16, E_λ  = 241.185125
# 		Σχ²: 	 1310.188 | 	 base: 1295.842
# 		14.346		<=		28		=>		✓
#
# Prior ladder check, deleted 17, E_λ  = 242.68303
# 		Σχ²: 	 1296.266 | 	 base: 1295.842
# 		0.424		<=		28		=>		✓
#
# Prior ladder check, deleted 18, E_λ  = 243.321134
# 		Σχ²: 	 1296.138 | 	 base: 1295.842
# 		0.296		<=		28		=>		✓
#
# Prior ladder check, deleted 19, E_λ  = 245.248499
# 		Σχ²: 	 54457.04 | 	 base: 1295.842
# 		53161.198		>		28		=>		✗
#
# Prior ladder check, deleted 20, E_λ  = 246.100774
# 		Σχ²: 	 6471.149 | 	 base: 1295.842
# 		5175.307		>		28		=>		✗
#
# Prior ladder check, deleted 21, E_λ  = 248.804101
# 		Σχ²: 	 1302.905 | 	 base: 1295.842
# 		7.063		<=		28		=>		✓
#
# Prior ladder check, deleted 22, E_λ  = 200.23693
# 		Σχ²: 	 1298.554 | 	 base: 1295.842
# 		2.712		<=		28		=>		✓
#
# Prior ladder check, deleted 23, E_λ  = 202.633701
# 		Σχ²: 	 1314.607 | 	 base: 1295.842
# 		18.765		<=		28		=>		✓
#
# Prior ladder check, deleted 24, E_λ  = 203.767572
# 		Σχ²: 	 1318.733 | 	 base: 1295.842
# 		22.891		<=		28		=>		✓
#
# Prior ladder check, deleted 25, E_λ  = 213.021383
# 		Σχ²: 	 1351.968 | 	 base: 1295.842
# 		56.126		>		28		=>		✗
#
# Prior ladder check, deleted 26, E_λ  = 213.39405
# 		Σχ²: 	 1459.789 | 	 base: 1295.842
# 		163.947		>		28		=>		✗
#
# Prior ladder check, deleted 27, E_λ  = 216.63784
# 		Σχ²: 	 1314.941 | 	 base: 1295.842
# 		19.099		<=		28		=>		✓
#
# Prior ladder check, deleted 28, E_λ  = 219.20721
# 		Σχ²: 	 1325.461 | 	 base: 1295.842
# 		29.619		>		28		=>		✗
#
# Prior ladder check, deleted 29, E_λ  = 221.572712
# 		Σχ²: 	 1460.594 | 	 base: 1295.842
# 		164.752		>		28		=>		✗
#
# Prior ladder check, deleted 30, E_λ  = 223.729373
# 		Σχ²: 	 1305.57 | 	 base: 1295.842
# 		9.728		<=		28		=>		✓
#
# Prior ladder check, deleted 31, E_λ  = 226.543004
# 		Σχ²: 	 1305.784 | 	 base: 1295.842
# 		9.942		<=		28		=>		✓
#
# Prior ladder check, deleted 32, E_λ  = 229.292794
# 		Σχ²: 	 1297.014 | 	 base: 1295.842
# 		1.172		<=		28		=>		✓
#
# Prior ladder check, deleted 33, E_λ  = 235.195224
# 		Σχ²: 	 1529.536 | 	 base: 1295.842
# 		233.694		>		28		=>		✗
#
# Prior ladder check, deleted 34, E_λ  = 237.252857
# 		Σχ²: 	 1305.769 | 	 base: 1295.842
# 		9.927		<=		28		=>		✓
#
# Prior ladder check, deleted 35, E_λ  = 238.578276
# 		Σχ²: 	 3015.81 | 	 base: 1295.842
# 		1719.968		>		28		=>		✗
#
# Prior ladder check, deleted 36, E_λ  = 241.183618
# 		Σχ²: 	 1310.316 | 	 base: 1295.842
# 		14.474		<=		28		=>		✓
#
# Prior ladder check, deleted 37, E_λ  = 242.698702
# 		Σχ²: 	 3603.13 | 	 base: 1295.842
# 		2307.288		>		28		=>		✗
#
#
# Priors passed the test...23
# Best model found 18:
# Σχ²: 	 1296.138
#
#
# Starting "deep" fitting of best initial guess by chi2...
#
# 	 proc_time 38.94784355163574  s
#
# 	 Benefit in chi2: 0.29599999999982174, while initial benefit for 20 iter. was 0.29599999999982174
# Deep fitting decision about model selection:
#
# 	 Before: 1296.138
# 	 After: 1296.138
#
# Deep fitting stage. Results
#              E         Gn1          Gg  varyE  varyGg  varyGn1  J_ID
# 0   200.236284    0.144070   51.081415    1.0     1.0      1.0   1.0
# 1   202.611598    0.210388   46.107975    1.0     1.0      1.0   1.0
# 2   204.808973   76.293951   64.363475    1.0     1.0      1.0   1.0
# 3   212.341997    3.142673   11.815223    1.0     1.0      1.0   1.0
# 4   213.356652   56.833616   46.169777    1.0     1.0      1.0   1.0
# 5   216.578789    0.223826   24.666592    1.0     1.0      1.0   1.0
# 6   219.326684   11.947380   58.106186    1.0     1.0      1.0   1.0
# 7   221.559970    0.285675   48.608579    1.0     1.0      1.0   1.0
# 8   221.557688    0.131624   58.490034    1.0     1.0      1.0   1.0
# 9   223.776780    0.468516   11.511978    1.0     1.0      1.0   1.0
# 10  226.602771    0.406262   22.677167    1.0     1.0      1.0   1.0
# 11  229.386997   26.883803   69.044669    1.0     1.0      1.0   1.0
# 12  232.547213    0.284037   28.629198    1.0     1.0      1.0   1.0
# 13  234.556662  135.069462  105.173061    1.0     1.0      1.0   1.0
# 14  236.783550    0.336449   60.451852    1.0     1.0      1.0   1.0
# 15  238.428410    0.478412   51.176651    1.0     1.0      1.0   1.0
# 16  241.185125    0.559211   43.248329    1.0     1.0      1.0   1.0
# 17  242.683030    0.231676   52.202944    1.0     1.0      1.0   1.0
# 18  245.248499  213.632656   68.699498    1.0     1.0      1.0   1.0
# 19  246.100774   83.966735   66.706910    1.0     1.0      1.0   1.0
# 20  248.804101    0.485415   48.369042    1.0     1.0      1.0   1.0
# 21  200.236930    0.152413   41.332686    1.0     1.0      1.0   2.0
# 22  202.633701    0.253947   37.401422    1.0     1.0      1.0   2.0
# 23  203.767572    0.420571   25.062147    1.0     1.0      1.0   2.0
# 24  213.021383    4.085500   40.667936    1.0     1.0      1.0   2.0
# 25  213.394050   17.276807   44.138169    1.0     1.0      1.0   2.0
# 26  216.637840    0.443920   13.740468    1.0     1.0      1.0   2.0
# 27  219.207210    1.661404   95.212083    1.0     1.0      1.0   2.0
# 28  221.572712    1.549064    7.164831    1.0     1.0      1.0   2.0
# 29  223.729373    0.270985   13.636171    1.0     1.0      1.0   2.0
# 30  226.543004    0.268355   23.946280    1.0     1.0      1.0   2.0
# 31  229.292794    0.214971   39.695564    1.0     1.0      1.0   2.0
# 32  235.195224   10.427630    0.098166    1.0     1.0      1.0   2.0
# 33  237.252857    0.517471   42.208938    1.0     1.0      1.0   2.0
# 34  238.578276   11.871784   76.592792    1.0     1.0      1.0   2.0
# 35  241.183618    0.434821   41.869788    1.0     1.0      1.0   2.0
# 36  242.698702   14.291012   62.107392    1.0     1.0      1.0   2.0
#
# Current N_res: 37
# Level 38 passed the test: True
# End of deep fitting stage...
#
#
# Level time: 49.0 sec
# Total elapsed time: 156.0 sec
# time per res.: 52.0 sec
#
#
# ****************************************
#
# Skipping stopping by chi2 test, going to 1 res model
# ****************************************
# Current level: 37
# 	 Searching for models with 36 resonances...
# ****************************************
#
#
# 	 init_sol_level_37
# 	 [419.143, 876.995]
#
# Prior ladder check, deleted 0, E_λ  = 200.236284
# 		Σχ²: 	 1297.567 | 	 base: 1296.138
# 		1.429		<=		28		=>		✓
#
# Prior ladder check, deleted 1, E_λ  = 202.611598
# 		Σχ²: 	 1303.686 | 	 base: 1296.138
# 		7.548		<=		28		=>		✓
#
# Prior ladder check, deleted 2, E_λ  = 204.808973
# 		Σχ²: 	 31171.82 | 	 base: 1296.138
# 		29875.682		>		28		=>		✗
#
# Prior ladder check, deleted 3, E_λ  = 212.341997
# 		Σχ²: 	 1483.487 | 	 base: 1296.138
# 		187.349		>		28		=>		✗
#
# Prior ladder check, deleted 4, E_λ  = 213.356652
# 		Σχ²: 	 3676.391 | 	 base: 1296.138
# 		2380.253		>		28		=>		✗
#
# Prior ladder check, deleted 5, E_λ  = 216.578789
# 		Σχ²: 	 1299.343 | 	 base: 1296.138
# 		3.205		<=		28		=>		✓
#
# Prior ladder check, deleted 6, E_λ  = 219.326684
# 		Σχ²: 	 2538.99 | 	 base: 1296.138
# 		1242.852		>		28		=>		✗
#
# Prior ladder check, deleted 7, E_λ  = 221.55997
# 		Σχ²: 	 1301.454 | 	 base: 1296.138
# 		5.316		<=		28		=>		✓
#
# Prior ladder check, deleted 8, E_λ  = 221.557688
# 		Σχ²: 	 1297.665 | 	 base: 1296.138
# 		1.527		<=		28		=>		✓
#
# Prior ladder check, deleted 9, E_λ  = 223.77678
# 		Σχ²: 	 1312.856 | 	 base: 1296.138
# 		16.718		<=		28		=>		✓
#
# Prior ladder check, deleted 10, E_λ  = 226.602771
# 		Σχ²: 	 1309.185 | 	 base: 1296.138
# 		13.047		<=		28		=>		✓
#
# Prior ladder check, deleted 11, E_λ  = 229.386997
# 		Σχ²: 	 5568.65 | 	 base: 1296.138
# 		4272.512		>		28		=>		✗
#
# Prior ladder check, deleted 12, E_λ  = 232.547213
# 		Σχ²: 	 1300.142 | 	 base: 1296.138
# 		4.004		<=		28		=>		✓
#
# Prior ladder check, deleted 13, E_λ  = 234.556662
# 		Σχ²: 	 37242.09 | 	 base: 1296.138
# 		35945.952		>		28		=>		✗
#
# Prior ladder check, deleted 14, E_λ  = 236.78355
# 		Σχ²: 	 1298.886 | 	 base: 1296.138
# 		2.748		<=		28		=>		✓
#
# Prior ladder check, deleted 15, E_λ  = 238.42841
# 		Σχ²: 	 1297.689 | 	 base: 1296.138
# 		1.551		<=		28		=>		✓
#
# Prior ladder check, deleted 16, E_λ  = 241.185125
# 		Σχ²: 	 1310.638 | 	 base: 1296.138
# 		14.5		<=		28		=>		✓
#
# Prior ladder check, deleted 17, E_λ  = 242.68303
# 		Σχ²: 	 1296.883 | 	 base: 1296.138
# 		0.745		<=		28		=>		✓
#
# Prior ladder check, deleted 18, E_λ  = 245.248499
# 		Σχ²: 	 54466.56 | 	 base: 1296.138
# 		53170.422		>		28		=>		✗
#
# Prior ladder check, deleted 19, E_λ  = 246.100774
# 		Σχ²: 	 6475.505 | 	 base: 1296.138
# 		5179.367		>		28		=>		✗
#
# Prior ladder check, deleted 20, E_λ  = 248.804101
# 		Σχ²: 	 1303.225 | 	 base: 1296.138
# 		7.087		<=		28		=>		✓
#
# Prior ladder check, deleted 21, E_λ  = 200.23693
# 		Σχ²: 	 1298.845 | 	 base: 1296.138
# 		2.707		<=		28		=>		✓
#
# Prior ladder check, deleted 22, E_λ  = 202.633701
# 		Σχ²: 	 1314.892 | 	 base: 1296.138
# 		18.754		<=		28		=>		✓
#
# Prior ladder check, deleted 23, E_λ  = 203.767572
# 		Σχ²: 	 1319.012 | 	 base: 1296.138
# 		22.874		<=		28		=>		✓
#
# Prior ladder check, deleted 24, E_λ  = 213.021383
# 		Σχ²: 	 1352.213 | 	 base: 1296.138
# 		56.075		>		28		=>		✗
#
# Prior ladder check, deleted 25, E_λ  = 213.39405
# 		Σχ²: 	 1459.977 | 	 base: 1296.138
# 		163.839		>		28		=>		✗
#
# Prior ladder check, deleted 26, E_λ  = 216.63784
# 		Σχ²: 	 1315.22 | 	 base: 1296.138
# 		19.082		<=		28		=>		✓
#
# Prior ladder check, deleted 27, E_λ  = 219.20721
# 		Σχ²: 	 1325.713 | 	 base: 1296.138
# 		29.575		>		28		=>		✗
#
# Prior ladder check, deleted 28, E_λ  = 221.572712
# 		Σχ²: 	 1460.831 | 	 base: 1296.138
# 		164.693		>		28		=>		✗
#
# Prior ladder check, deleted 29, E_λ  = 223.729373
# 		Σχ²: 	 1305.857 | 	 base: 1296.138
# 		9.719		<=		28		=>		✓
#
# Prior ladder check, deleted 30, E_λ  = 226.543004
# 		Σχ²: 	 1306.071 | 	 base: 1296.138
# 		9.933		<=		28		=>		✓
#
# Prior ladder check, deleted 31, E_λ  = 229.292794
# 		Σχ²: 	 1297.307 | 	 base: 1296.138
# 		1.169		<=		28		=>		✓
#
# Prior ladder check, deleted 32, E_λ  = 235.195224
# 		Σχ²: 	 1529.679 | 	 base: 1296.138
# 		233.541		>		28		=>		✗
#
# Prior ladder check, deleted 33, E_λ  = 237.252857
# 		Σχ²: 	 1306.054 | 	 base: 1296.138
# 		9.916		<=		28		=>		✓
#
# Prior ladder check, deleted 34, E_λ  = 238.578276
# 		Σχ²: 	 3016.46 | 	 base: 1296.138
# 		1720.322		>		28		=>		✗
#
# Prior ladder check, deleted 35, E_λ  = 241.183618
# 		Σχ²: 	 1310.783 | 	 base: 1296.138
# 		14.645		<=		28		=>		✓
#
# Prior ladder check, deleted 36, E_λ  = 242.698702
# 		Σχ²: 	 3632.31 | 	 base: 1296.138
# 		2336.172		>		28		=>		✗
#
#
# Priors passed the test...22
# Best model found 17:
# Σχ²: 	 1296.883
#
#
# Starting "deep" fitting of best initial guess by chi2...
#
# 	 proc_time 35.98767638206482  s
#
# 	 Benefit in chi2: 0.7450000000001182, while initial benefit for 20 iter. was 0.7450000000001182
# Deep fitting decision about model selection:
#
# 	 Before: 1296.883
# 	 After: 1296.883
#
# Deep fitting stage. Results
#              E         Gn1          Gg  varyE  varyGg  varyGn1  J_ID
# 0   200.236284    0.144070   51.081415    1.0     1.0      1.0   1.0
# 1   202.611598    0.210388   46.107975    1.0     1.0      1.0   1.0
# 2   204.808973   76.293951   64.363475    1.0     1.0      1.0   1.0
# 3   212.341997    3.142673   11.815223    1.0     1.0      1.0   1.0
# 4   213.356652   56.833616   46.169777    1.0     1.0      1.0   1.0
# 5   216.578789    0.223826   24.666592    1.0     1.0      1.0   1.0
# 6   219.326684   11.947380   58.106186    1.0     1.0      1.0   1.0
# 7   221.559970    0.285675   48.608579    1.0     1.0      1.0   1.0
# 8   221.557688    0.131624   58.490034    1.0     1.0      1.0   1.0
# 9   223.776780    0.468516   11.511978    1.0     1.0      1.0   1.0
# 10  226.602771    0.406262   22.677167    1.0     1.0      1.0   1.0
# 11  229.386997   26.883803   69.044669    1.0     1.0      1.0   1.0
# 12  232.547213    0.284037   28.629198    1.0     1.0      1.0   1.0
# 13  234.556662  135.069462  105.173061    1.0     1.0      1.0   1.0
# 14  236.783550    0.336449   60.451852    1.0     1.0      1.0   1.0
# 15  238.428410    0.478412   51.176651    1.0     1.0      1.0   1.0
# 16  241.185125    0.559211   43.248329    1.0     1.0      1.0   1.0
# 17  245.248499  213.632656   68.699498    1.0     1.0      1.0   1.0
# 18  246.100774   83.966735   66.706910    1.0     1.0      1.0   1.0
# 19  248.804101    0.485415   48.369042    1.0     1.0      1.0   1.0
# 20  200.236930    0.152413   41.332686    1.0     1.0      1.0   2.0
# 21  202.633701    0.253947   37.401422    1.0     1.0      1.0   2.0
# 22  203.767572    0.420571   25.062147    1.0     1.0      1.0   2.0
# 23  213.021383    4.085500   40.667936    1.0     1.0      1.0   2.0
# 24  213.394050   17.276807   44.138169    1.0     1.0      1.0   2.0
# 25  216.637840    0.443920   13.740468    1.0     1.0      1.0   2.0
# 26  219.207210    1.661404   95.212083    1.0     1.0      1.0   2.0
# 27  221.572712    1.549064    7.164831    1.0     1.0      1.0   2.0
# 28  223.729373    0.270985   13.636171    1.0     1.0      1.0   2.0
# 29  226.543004    0.268355   23.946280    1.0     1.0      1.0   2.0
# 30  229.292794    0.214971   39.695564    1.0     1.0      1.0   2.0
# 31  235.195224   10.427630    0.098166    1.0     1.0      1.0   2.0
# 32  237.252857    0.517471   42.208938    1.0     1.0      1.0   2.0
# 33  238.578276   11.871784   76.592792    1.0     1.0      1.0   2.0
# 34  241.183618    0.434821   41.869788    1.0     1.0      1.0   2.0
# 35  242.698702   14.291012   62.107392    1.0     1.0      1.0   2.0
#
# Current N_res: 36
# Level 37 passed the test: True
# End of deep fitting stage...
#
#
# Level time: 46.8 sec
# Total elapsed time: 202.7 sec
# time per res.: 50.7 sec
#
#
# ****************************************
#
# Skipping stopping by chi2 test, going to 1 res model
# ****************************************
# Current level: 36
# 	 Searching for models with 35 resonances...
# ****************************************
#
#
# 	 init_sol_level_36
# 	 [419.813, 877.07]
#
# Prior ladder check, deleted 0, E_λ  = 200.236284
# 		Σχ²: 	 1298.308 | 	 base: 1296.883
# 		1.425		<=		28		=>		✓
#
# Prior ladder check, deleted 1, E_λ  = 202.611598
# 		Σχ²: 	 1304.424 | 	 base: 1296.883
# 		7.541		<=		28		=>		✓
#
# Prior ladder check, deleted 2, E_λ  = 204.808973
# 		Σχ²: 	 31170.5 | 	 base: 1296.883
# 		29873.617		>		28		=>		✗
#
# Prior ladder check, deleted 3, E_λ  = 212.341997
# 		Σχ²: 	 1484.121 | 	 base: 1296.883
# 		187.238		>		28		=>		✗
#
# Prior ladder check, deleted 4, E_λ  = 213.356652
# 		Σχ²: 	 3676.471 | 	 base: 1296.883
# 		2379.588		>		28		=>		✗
#
# Prior ladder check, deleted 5, E_λ  = 216.578789
# 		Σχ²: 	 1300.079 | 	 base: 1296.883
# 		3.196		<=		28		=>		✓
#
# Prior ladder check, deleted 6, E_λ  = 219.326684
# 		Σχ²: 	 2539.36 | 	 base: 1296.883
# 		1242.477		>		28		=>		✗
#
# Prior ladder check, deleted 7, E_λ  = 221.55997
# 		Σχ²: 	 1302.189 | 	 base: 1296.883
# 		5.306		<=		28		=>		✓
#
# Prior ladder check, deleted 8, E_λ  = 221.557688
# 		Σχ²: 	 1298.406 | 	 base: 1296.883
# 		1.523		<=		28		=>		✓
#
# Prior ladder check, deleted 9, E_λ  = 223.77678
# 		Σχ²: 	 1313.585 | 	 base: 1296.883
# 		16.702		<=		28		=>		✓
#
# Prior ladder check, deleted 10, E_λ  = 226.602771
# 		Σχ²: 	 1309.918 | 	 base: 1296.883
# 		13.035		<=		28		=>		✓
#
# Prior ladder check, deleted 11, E_λ  = 229.386997
# 		Σχ²: 	 5568.65 | 	 base: 1296.883
# 		4271.767		>		28		=>		✗
#
# Prior ladder check, deleted 12, E_λ  = 232.547213
# 		Σχ²: 	 1300.88 | 	 base: 1296.883
# 		3.997		<=		28		=>		✓
#
# Prior ladder check, deleted 13, E_λ  = 234.556662
# 		Σχ²: 	 37240.14 | 	 base: 1296.883
# 		35943.257		>		28		=>		✗
#
# Prior ladder check, deleted 14, E_λ  = 236.78355
# 		Σχ²: 	 1299.62 | 	 base: 1296.883
# 		2.737		<=		28		=>		✓
#
# Prior ladder check, deleted 15, E_λ  = 238.42841
# 		Σχ²: 	 1298.441 | 	 base: 1296.883
# 		1.558		<=		28		=>		✓
#
# Prior ladder check, deleted 16, E_λ  = 241.185125
# 		Σχ²: 	 1311.562 | 	 base: 1296.883
# 		14.679		<=		28		=>		✓
#
# Prior ladder check, deleted 17, E_λ  = 245.248499
# 		Σχ²: 	 54471.42 | 	 base: 1296.883
# 		53174.537		>		28		=>		✗
#
# Prior ladder check, deleted 18, E_λ  = 246.100774
# 		Σχ²: 	 6480.846 | 	 base: 1296.883
# 		5183.963		>		28		=>		✗
#
# Prior ladder check, deleted 19, E_λ  = 248.804101
# 		Σχ²: 	 1304.033 | 	 base: 1296.883
# 		7.15		<=		28		=>		✓
#
# Prior ladder check, deleted 20, E_λ  = 200.23693
# 		Σχ²: 	 1299.584 | 	 base: 1296.883
# 		2.701		<=		28		=>		✓
#
# Prior ladder check, deleted 21, E_λ  = 202.633701
# 		Σχ²: 	 1315.625 | 	 base: 1296.883
# 		18.742		<=		28		=>		✓
#
# Prior ladder check, deleted 22, E_λ  = 203.767572
# 		Σχ²: 	 1319.738 | 	 base: 1296.883
# 		22.855		<=		28		=>		✓
#
# Prior ladder check, deleted 23, E_λ  = 213.021383
# 		Σχ²: 	 1352.896 | 	 base: 1296.883
# 		56.013		>		28		=>		✗
#
# Prior ladder check, deleted 24, E_λ  = 213.39405
# 		Σχ²: 	 1460.581 | 	 base: 1296.883
# 		163.698		>		28		=>		✗
#
# Prior ladder check, deleted 25, E_λ  = 216.63784
# 		Σχ²: 	 1315.944 | 	 base: 1296.883
# 		19.061		<=		28		=>		✓
#
# Prior ladder check, deleted 26, E_λ  = 219.20721
# 		Σχ²: 	 1326.406 | 	 base: 1296.883
# 		29.523		>		28		=>		✗
#
# Prior ladder check, deleted 27, E_λ  = 221.572712
# 		Σχ²: 	 1461.505 | 	 base: 1296.883
# 		164.622		>		28		=>		✗
#
# Prior ladder check, deleted 28, E_λ  = 223.729373
# 		Σχ²: 	 1306.59 | 	 base: 1296.883
# 		9.707		<=		28		=>		✓
#
# Prior ladder check, deleted 29, E_λ  = 226.543004
# 		Σχ²: 	 1306.806 | 	 base: 1296.883
# 		9.923		<=		28		=>		✓
#
# Prior ladder check, deleted 30, E_λ  = 229.292794
# 		Σχ²: 	 1298.048 | 	 base: 1296.883
# 		1.165		<=		28		=>		✓
#
# Prior ladder check, deleted 31, E_λ  = 235.195224
# 		Σχ²: 	 1530.176 | 	 base: 1296.883
# 		233.293		>		28		=>		✗
#
# Prior ladder check, deleted 32, E_λ  = 237.252857
# 		Σχ²: 	 1306.788 | 	 base: 1296.883
# 		9.905		<=		28		=>		✓
#
# Prior ladder check, deleted 33, E_λ  = 238.578276
# 		Σχ²: 	 3017.59 | 	 base: 1296.883
# 		1720.707		>		28		=>		✗
#
# Prior ladder check, deleted 34, E_λ  = 241.183618
# 		Σχ²: 	 1311.717 | 	 base: 1296.883
# 		14.834		<=		28		=>		✓
#
# Prior ladder check, deleted 35, E_λ  = 242.698702
# 		Σχ²: 	 3729.83 | 	 base: 1296.883
# 		2432.947		>		28		=>		✗
#
#
# Priors passed the test...21
# Best model found 30:
# Σχ²: 	 1298.048
#
#
# Starting "deep" fitting of best initial guess by chi2...
#
# 	 proc_time 40.85282492637634  s
#
# 	 Benefit in chi2: 1.1649999999999636, while initial benefit for 20 iter. was 1.1649999999999636
# Deep fitting decision about model selection:
#
# 	 Before: 1298.048
# 	 After: 1298.048
#
# Deep fitting stage. Results
#              E         Gn1          Gg  varyE  varyGg  varyGn1  J_ID
# 0   200.236284    0.144070   51.081415    1.0     1.0      1.0   1.0
# 1   202.611598    0.210388   46.107975    1.0     1.0      1.0   1.0
# 2   204.808973   76.293951   64.363475    1.0     1.0      1.0   1.0
# 3   212.341997    3.142673   11.815223    1.0     1.0      1.0   1.0
# 4   213.356652   56.833616   46.169777    1.0     1.0      1.0   1.0
# 5   216.578789    0.223826   24.666592    1.0     1.0      1.0   1.0
# 6   219.326684   11.947380   58.106186    1.0     1.0      1.0   1.0
# 7   221.559970    0.285675   48.608579    1.0     1.0      1.0   1.0
# 8   221.557688    0.131624   58.490034    1.0     1.0      1.0   1.0
# 9   223.776780    0.468516   11.511978    1.0     1.0      1.0   1.0
# 10  226.602771    0.406262   22.677167    1.0     1.0      1.0   1.0
# 11  229.386997   26.883803   69.044669    1.0     1.0      1.0   1.0
# 12  232.547213    0.284037   28.629198    1.0     1.0      1.0   1.0
# 13  234.556662  135.069462  105.173061    1.0     1.0      1.0   1.0
# 14  236.783550    0.336449   60.451852    1.0     1.0      1.0   1.0
# 15  238.428410    0.478412   51.176651    1.0     1.0      1.0   1.0
# 16  241.185125    0.559211   43.248329    1.0     1.0      1.0   1.0
# 17  245.248499  213.632656   68.699498    1.0     1.0      1.0   1.0
# 18  246.100774   83.966735   66.706910    1.0     1.0      1.0   1.0
# 19  248.804101    0.485415   48.369042    1.0     1.0      1.0   1.0
# 20  200.236930    0.152413   41.332686    1.0     1.0      1.0   2.0
# 21  202.633701    0.253947   37.401422    1.0     1.0      1.0   2.0
# 22  203.767572    0.420571   25.062147    1.0     1.0      1.0   2.0
# 23  213.021383    4.085500   40.667936    1.0     1.0      1.0   2.0
# 24  213.394050   17.276807   44.138169    1.0     1.0      1.0   2.0
# 25  216.637840    0.443920   13.740468    1.0     1.0      1.0   2.0
# 26  219.207210    1.661404   95.212083    1.0     1.0      1.0   2.0
# 27  221.572712    1.549064    7.164831    1.0     1.0      1.0   2.0
# 28  223.729373    0.270985   13.636171    1.0     1.0      1.0   2.0
# 29  226.543004    0.268355   23.946280    1.0     1.0      1.0   2.0
# 30  235.195224   10.427630    0.098166    1.0     1.0      1.0   2.0
# 31  237.252857    0.517471   42.208938    1.0     1.0      1.0   2.0
# 32  238.578276   11.871784   76.592792    1.0     1.0      1.0   2.0
# 33  241.183618    0.434821   41.869788    1.0     1.0      1.0   2.0
# 34  242.698702   14.291012   62.107392    1.0     1.0      1.0   2.0
#
# Current N_res: 35
# Level 36 passed the test: True
# End of deep fitting stage...
#
#
# Level time: 51.0 sec
# Total elapsed time: 253.7 sec
# time per res.: 50.7 sec
#
#
# ****************************************
#
# Skipping stopping by chi2 test, going to 1 res model
# ****************************************
# Current level: 35
# 	 Searching for models with 34 resonances...
# ****************************************
#
#
# 	 init_sol_level_35
# 	 [421.128, 876.92]
#
# Prior ladder check, deleted 0, E_λ  = 200.236284
# 		Σχ²: 	 1299.468 | 	 base: 1298.048
# 		1.42		<=		28		=>		✓
#
# Prior ladder check, deleted 1, E_λ  = 202.611598
# 		Σχ²: 	 1305.581 | 	 base: 1298.048
# 		7.533		<=		28		=>		✓
#
# Prior ladder check, deleted 2, E_λ  = 204.808973
# 		Σχ²: 	 31169.13 | 	 base: 1298.048
# 		29871.082		>		28		=>		✗
#
# Prior ladder check, deleted 3, E_λ  = 212.341997
# 		Σχ²: 	 1485.16 | 	 base: 1298.048
# 		187.112		>		28		=>		✗
#
# Prior ladder check, deleted 4, E_λ  = 213.356652
# 		Σχ²: 	 3676.862 | 	 base: 1298.048
# 		2378.814		>		28		=>		✗
#
# Prior ladder check, deleted 5, E_λ  = 216.578789
# 		Σχ²: 	 1301.234 | 	 base: 1298.048
# 		3.186		<=		28		=>		✓
#
# Prior ladder check, deleted 6, E_λ  = 219.326684
# 		Σχ²: 	 2540.07 | 	 base: 1298.048
# 		1242.022		>		28		=>		✗
#
# Prior ladder check, deleted 7, E_λ  = 221.55997
# 		Σχ²: 	 1303.343 | 	 base: 1298.048
# 		5.295		<=		28		=>		✓
#
# Prior ladder check, deleted 8, E_λ  = 221.557688
# 		Σχ²: 	 1299.566 | 	 base: 1298.048
# 		1.518		<=		28		=>		✓
#
# Prior ladder check, deleted 9, E_λ  = 223.77678
# 		Σχ²: 	 1314.741 | 	 base: 1298.048
# 		16.693		<=		28		=>		✓
#
# Prior ladder check, deleted 10, E_λ  = 226.602771
# 		Σχ²: 	 1311.25 | 	 base: 1298.048
# 		13.202		<=		28		=>		✓
#
# Prior ladder check, deleted 11, E_λ  = 229.386997
# 		Σχ²: 	 5737.79 | 	 base: 1298.048
# 		4439.742		>		28		=>		✗
#
# Prior ladder check, deleted 12, E_λ  = 232.547213
# 		Σχ²: 	 1302.09 | 	 base: 1298.048
# 		4.042		<=		28		=>		✓
#
# Prior ladder check, deleted 13, E_λ  = 234.556662
# 		Σχ²: 	 37242.67 | 	 base: 1298.048
# 		35944.622		>		28		=>		✗
#
# Prior ladder check, deleted 14, E_λ  = 236.78355
# 		Σχ²: 	 1300.784 | 	 base: 1298.048
# 		2.736		<=		28		=>		✓
#
# Prior ladder check, deleted 15, E_λ  = 238.42841
# 		Σχ²: 	 1299.601 | 	 base: 1298.048
# 		1.553		<=		28		=>		✓
#
# Prior ladder check, deleted 16, E_λ  = 241.185125
# 		Σχ²: 	 1312.718 | 	 base: 1298.048
# 		14.67		<=		28		=>		✓
#
# Prior ladder check, deleted 17, E_λ  = 245.248499
# 		Σχ²: 	 54472.38 | 	 base: 1298.048
# 		53174.332		>		28		=>		✗
#
# Prior ladder check, deleted 18, E_λ  = 246.100774
# 		Σχ²: 	 6481.31 | 	 base: 1298.048
# 		5183.262		>		28		=>		✗
#
# Prior ladder check, deleted 19, E_λ  = 248.804101
# 		Σχ²: 	 1305.19 | 	 base: 1298.048
# 		7.142		<=		28		=>		✓
#
# Prior ladder check, deleted 20, E_λ  = 200.23693
# 		Σχ²: 	 1300.743 | 	 base: 1298.048
# 		2.695		<=		28		=>		✓
#
# Prior ladder check, deleted 21, E_λ  = 202.633701
# 		Σχ²: 	 1316.776 | 	 base: 1298.048
# 		18.728		<=		28		=>		✓
#
# Prior ladder check, deleted 22, E_λ  = 203.767572
# 		Σχ²: 	 1320.88 | 	 base: 1298.048
# 		22.832		<=		28		=>		✓
#
# Prior ladder check, deleted 23, E_λ  = 213.021383
# 		Σχ²: 	 1353.993 | 	 base: 1298.048
# 		55.945		>		28		=>		✗
#
# Prior ladder check, deleted 24, E_λ  = 213.39405
# 		Σχ²: 	 1461.601 | 	 base: 1298.048
# 		163.553		>		28		=>		✗
#
# Prior ladder check, deleted 25, E_λ  = 216.63784
# 		Σχ²: 	 1317.084 | 	 base: 1298.048
# 		19.036		<=		28		=>		✓
#
# Prior ladder check, deleted 26, E_λ  = 219.20721
# 		Σχ²: 	 1327.515 | 	 base: 1298.048
# 		29.467		>		28		=>		✗
#
# Prior ladder check, deleted 27, E_λ  = 221.572712
# 		Σχ²: 	 1462.586 | 	 base: 1298.048
# 		164.538		>		28		=>		✗
#
# Prior ladder check, deleted 28, E_λ  = 223.729373
# 		Σχ²: 	 1307.749 | 	 base: 1298.048
# 		9.701		<=		28		=>		✓
#
# Prior ladder check, deleted 29, E_λ  = 226.543004
# 		Σχ²: 	 1308.11 | 	 base: 1298.048
# 		10.062		<=		28		=>		✓
#
# Prior ladder check, deleted 30, E_λ  = 235.195224
# 		Σχ²: 	 1531.169 | 	 base: 1298.048
# 		233.121		>		28		=>		✗
#
# Prior ladder check, deleted 31, E_λ  = 237.252857
# 		Σχ²: 	 1307.944 | 	 base: 1298.048
# 		9.896		<=		28		=>		✓
#
# Prior ladder check, deleted 32, E_λ  = 238.578276
# 		Σχ²: 	 3018.48 | 	 base: 1298.048
# 		1720.432		>		28		=>		✗
#
# Prior ladder check, deleted 33, E_λ  = 241.183618
# 		Σχ²: 	 1312.873 | 	 base: 1298.048
# 		14.825		<=		28		=>		✓
#
# Prior ladder check, deleted 34, E_λ  = 242.698702
# 		Σχ²: 	 3730.61 | 	 base: 1298.048
# 		2432.562		>		28		=>		✗
#
#
# Priors passed the test...20
# Best model found 0:
# Σχ²: 	 1299.4679999999998
#
#
# Starting "deep" fitting of best initial guess by chi2...

# %%
# can we save the history not to refit all the time?

case_data = {
        'datasets' : datasets,
        'covariance_data' : covariance_data,
    'experiments': experiments,
    'true_chars': true_chars,
    'Ta_pair': Ta_pair
}

saved_hist = elim_addit_funcs.save_obj_as_pkl(folder_name=savefolder, file_name='hist.pkl', obj=hist)
saved_data = elim_addit_funcs.save_obj_as_pkl(folder_name=savefolder, file_name='dataset.pkl', obj=case_data)

# %%
## Loading data from files to show the history
hist = elim_addit_funcs.load_obj_from_pkl(folder_name=savefolder, pkl_fname='hist.pkl')
case_data_loaded = elim_addit_funcs.load_obj_from_pkl(folder_name=savefolder, pkl_fname='dataset.pkl')
datasets = case_data_loaded['datasets']
covariance_data = case_data_loaded['covariance_data']
experiments = case_data_loaded['experiments']
true_chars = case_data_loaded['true_chars']
Ta_pair = case_data_loaded['Ta_pair']

# %%
true_chars.par

# %%
# just to show how much we aliminated with the given threshold value.
print(f'Eliminated from {hist.ladder_IN.shape[0]} res -> {hist.ladder_OUT.shape[0]}')
print(f'Elim took {np.round(hist.elim_tot_time,2)} sec')

# %%
# images production from history

prior_level = max(hist.elimination_history.keys())
prior_numres = hist.elimination_history[prior_level]['input_ladder'].shape[0]
print(f'Initial ladder, num of res.: {prior_numres}')

min_level_passed_test = prior_level # level - key in the hist..
min_N_res_passed_test = prior_level - 1

levels = []
N_ress = []
chi2_s = []

for level in hist.elimination_history.keys():
        
    numres = hist.elimination_history[level]['selected_ladder_chars'].par_post.shape[0]
    pass_test = hist.elimination_history[level]['final_model_passed_test']

    #print(f'level {level}, # of resonances: {numres},  passed the test: {pass_test}')

    if (pass_test and level<min_level_passed_test):
        min_level_passed_test = level

        min_N_res_passed_test = numres
    
    levels.append(level)
    chi2_s.append(np.sum(hist.elimination_history[level]['selected_ladder_chars'].chi2_post))
    N_ress.append(numres)

# plotting    

# differences in chi2 values between 2 models
chi2_diffs = np.diff(chi2_s, prepend=chi2_s[0]) 

fig, (ax1, ax2) = subplots(2, 1, figsize = fig_size, sharex=True, gridspec_kw={'height_ratios': [2, 1]})

# First subplot for the original chi2 values
ax1.plot(N_ress, chi2_s, marker='o')
ax1.axvline(x=min_N_res_passed_test, color='r', linestyle='--')

ax1.set_ylabel('$\chi^2$')
ax1.grid(True)

# changes in chi2

ax2.plot(N_ress, chi2_diffs, marker='o', color='green')
ax2.axvline(x=min_N_res_passed_test, color='r', linestyle='--')
ax2.set_xlabel(r'$N_{res}$')
ax2.set_ylabel('Change in $\chi^2$')
ax2.invert_xaxis()
ax2.grid(True)

tight_layout()
fig.savefig(savefolder+'hist_png', dpi=75)
show()

# %%
# plotting data
def show_plot_from_hist(
        datasets,
        experiments,
        true_chars,
        true_pars,

        level_to_compare: int,
        min_level_passed_test: int,
        elim_hist: dict,
        ):
    
    fits = elim_hist[level_to_compare]['selected_ladder_chars'].pw_post
    fits_chi2 = elim_hist[level_to_compare]['selected_ladder_chars'].chi2_post

    prior_fit = elim_hist[prior_level]['selected_ladder_chars'].pw
    priors_chi2 = elim_hist[prior_level]['selected_ladder_chars'].chi2

    # outfit
    fig = plot_datafits(datasets, experiments, 
        fits=fits, fits_chi2=fits_chi2,
        priors = prior_fit, priors_chi2=priors_chi2,
        true=datasets, true_chi2 = true_chars.chi2,
        true_pars = true_pars,
        fit_pars = elim_hist[level_to_compare]['selected_ladder_chars'].par_post,
        prior_pars = elim_hist[prior_level]['input_ladder'],
        title = f'Fit, Prior & True comparison, model # {level_to_compare}, best selected: {min_level_passed_test}',
        show_spingroups=True
        )
    fig.tight_layout()
    return fig

# %%
# select level num from saved history to compare
# note: always N_res = level-1
N_res_to_view = min_N_res_passed_test
level_to_compare = N_res_to_view+1

fig = show_plot_from_hist(datasets = datasets,
                          experiments=experiments,
                          true_chars = true_chars,
                          true_pars = true_chars.par,
                          level_to_compare=level_to_compare,
                          min_level_passed_test= min_level_passed_test,
                          elim_hist = hist.elimination_history
                          )

# %%
# animation of all steps
images = []

# creating images one by one
for level in hist.elimination_history.keys():

    fig = show_plot_from_hist(datasets = datasets,
                          experiments=experiments,
                          true_chars = true_chars,
                          true_pars = Ta_pair.resonance_ladder,
                          level_to_compare = level,
                          min_level_passed_test = min_level_passed_test,
                          elim_hist = hist.elimination_history
                          )

    img_name = savefolder+'comparison_'+str(level)+'.png' 
    images.append(img_name)
    fig.savefig(img_name, dpi=dpi)

# now create animation from this images
from PIL import Image
import imageio
import glob
import os

folder_path = savefolder
output_name = 'output.gif'

# Define different durations in seconds
start_duration = 3
intermediate_duration = 1.5
end_duration = 5.0

# Convert durations to milliseconds (as required by imageio)
start_duration_ms = start_duration * 1000
intermediate_duration_ms = intermediate_duration * 1000
end_duration_ms = end_duration * 1000

# Additional images to be added
additional_start_images = [savefolder+'true.png',
                           savefolder+'initial.png']  

additional_end_images = [savefolder+'hist_png.png']

# Combine all images in the required order
all_images = additional_start_images + images + additional_end_images


# Check and print the size of each image
for img_path in all_images:
    with Image.open(img_path) as img:
        print(f"{os.path.basename(img_path)} - Size: {img.size}")

# Create a list of images from the combined file list
images = [Image.open(f) for f in all_images]

# Output path for the animated GIF
output_path = os.path.join(folder_path, output_name)

# Create a list of durations corresponding to each image
durations = ([start_duration_ms] * len(additional_start_images) + 
             [intermediate_duration_ms] * len(images) + 
             [end_duration_ms] * len(additional_end_images))

# Save the animated GIF using imageio
imageio.mimsave(output_path, images, duration=durations) 

print(f"Animated GIF saved to {output_path}")

# %%
# table for analysis of the models - produce chi2

# sums - for all datasets
NLLW_s = []
chi2_s = []
aicc_s = []
bicc_s = []
N_res_s = []
test_pass = []

for level in hist.elimination_history.keys():
        
    numres = hist.elimination_history[level]['selected_ladder_chars'].par_post.shape[0]
    pass_test = hist.elimination_history[level]['final_model_passed_test']

    # print(f'level {level}, # of resonances: {numres},  passed the test: {pass_test}')
    cur_ch_dict = elim_addit_funcs.characterize_sol(Ta_pair=Ta_pair,
                     datasets=datasets,
                     experiments=experiments,
                     sol = hist.elimination_history[level]['selected_ladder_chars'],
                     covariance_data = covariance_data
                     )
    
    N_res_s.append(numres)
    test_pass.append(pass_test)
    chi2_s.append(sum(cur_ch_dict['chi2_stat']))
    aicc_s.append(sum(cur_ch_dict['aicc']))
    bicc_s.append(sum(cur_ch_dict['bicc']))
    NLLW_s.append(sum(cur_ch_dict['NLLW'].values()))


    # levels.append(level)
    # chi2_s.append(np.sum(hist.elimination_history[level]['selected_ladder_chars'].chi2_post))
    # N_ress.append(numres)
    print(cur_ch_dict )

# combine to one DataFrame
table_df = pd.DataFrame.from_dict({
    'N_res': N_res_s,
    'passed': test_pass,
    'sum_chi2': chi2_s,
    'sum_NLLW': NLLW_s,
    'sum_AICc': aicc_s,
    'sum_BICc': bicc_s

})
table_df

# %%
# save table
table_df.to_csv(path_or_buf=savefolder+'models_comparison_table.csv')

# %%
# compare 2 models plot..
# which space?

model1 = hist.elimination_history[18]['selected_ladder_chars']

model2 = hist.elimination_history[17]['selected_ladder_chars']

fig = plot_datafits(datasets, experiments, 
    fits=model1.pw_post, fits_chi2=model1.chi2_post, f_model_name='model1',
    priors=model2.pw_post, priors_chi2=model2.chi2_post, pr_model_name='model2',

     true=datasets, true_chi2 = true_chars.chi2, t_model_name ='true',
        true_pars = Ta_pair.resonance_ladder,
        fit_pars = model1.par_post,
        prior_pars = model2.par,
      
    title = 'Models Comparison',
    show_spingroups = False,
    fig_size = fig_size
    )

# %%
# TODO: analyze logic & funcs on found/not found, missed spin_groups, calc error on the fine grid.
